# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

print("Tourism Economics Research Environment")
print(f"Pandas: {pd.__version__}")
print(f"Numpy: {np.__version__}")
print(f"Statsmodels: {sm.__version__}")
print("Ready for research! 🚀")
# Out:
# Tourism Economics Research Environment
# Pandas: 3.0.3
# Numpy: 2.4.6
# Statsmodels: 0.14.6
# Ready for research! 🚀
